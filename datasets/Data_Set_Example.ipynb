# %% [markdown]
# import pandas as pd

# %%
import pandas as pd
data = import kagglehub

# Download latest version
path = kagglehub.dataset_download("anandaramg/apartment-cost-in-new-york-city")

print("Path to dataset files:", path)

# %%
data.head()

# %%
data["Job Type"]
data["Job Type"].value_counts()

# %%
data.info()
Lo que quiero aqui es mas o menos mi idea es que si hay datos vacios quitarlos
data.describe()
Con esta quisiera ver promedios, el minimo y el maximo, los percentiles
data.hist(figsize(16), bins = 30, edgecolor = "black")
estaria bien hacer algunos historigramas, podemos especificar el tamaño del grafico
Tenemos que ver que podemos limpiar para que hagamos buenas predicciones
