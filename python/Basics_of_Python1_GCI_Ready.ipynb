# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielRamos1171998/GCI-World-2026-September/blob/main/python/Basics_of_Python1.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # 🐍 Basics of Python 1
#
# > **GCI World 2026 — Learning Library**
#
# This notebook is part of the Python section of the learning library.
#
# ### 🔗 Navigation
#
# - [🏠 Learning Library — GitHub](https://github.com/GabrielRamos1171998/GCI-World-2026-September/blob/main/home/GCI_Learning_Library.ipynb)
# - [🏠 Learning Library — Colab](https://colab.research.google.com/github/GabrielRamos1171998/GCI-World-2026-September/blob/main/home/GCI_Learning_Library.ipynb)
# - [📄 This notebook — GitHub](https://github.com/GabrielRamos1171998/GCI-World-2026-September/blob/main/python/Basics_of_Python1.ipynb)
# - [🔵 This notebook — Open in Colab](https://colab.research.google.com/github/GabrielRamos1171998/GCI-World-2026-September/blob/main/python/Basics_of_Python1.ipynb)
#
# ---

# %% [markdown]
# # Basics of Python (by Gabriel Alonso Ramos Carrillo)

# %% [markdown]
# # Pythonの基礎 (ガブリエル・アロンソ・ラモス・カリージョ)

# %% [markdown]
# **Programming** refers to the process of designing and constructing a program (a set of instructions for the computer) for a specific purpose.
#
# **Jupyter Notebook** is a web-based interactive computing environment that allows you to write and execute code, visualize data, and combine narrative text in a single document.

# %% [markdown]
# **プログラミング**とは、特定の目的のために、コンピューターに実行させる一連の命令からなるプログラムを設計・作成することを指します。
#
# **Jupyter Notebook**は、**WEB**上で利用できるインタラクティブなコンピューティング環境です。一つのドキュメント内で、コードを書いて実行したり、データを可視化したり、説明用の文章を組み合わせたりすることができます。

# %% [markdown]
# # 🐍 Python Programming Language
#
# > **Python** is a high-level, general-purpose programming language known for its **simplicity, readability, and versatility**.
#
# Its extensive ecosystem of libraries and frameworks has made it one of the most widely used languages in software development, data science, artificial intelligence, automation, and scientific computing.
#
# ---
#
# ## ✨ Key Features of Python
#
# ### 1. 🏗️ High-Level Language
#
# Python abstracts away many low-level details of computer hardware and memory management. This allows developers to focus primarily on **solving problems and building applications** rather than dealing with hardware-specific instructions.
#
# ### 2. ⚙️ Interpreted and Interactive
#
# Python programs are executed through a Python interpreter, which makes it possible to run code interactively and test ideas quickly. This approach also facilitates **experimentation, debugging, and rapid development**.
#
# ### 3. 📖 Readable and Simple Syntax
#
# Maybe for me, Python's most distinctive characteristics is its emphasis on **code readability**.
#
# Instead of using braces `{}` to define code blocks, Python uses **indentation**, resulting in a clean and visually structured syntax. But sometimes is very hard to read if you don't take precautions (Depends of you, the good lecture of your code)
#
# ```python
# if temperature > 30:
#     print("It's a hot day!")
# ```
#
# ### 4. 🔄 Dynamically Typed
#
# Python is a **dynamically typed language**, meaning that variables do not require an explicit type declaration.
#
# ```python
# name = "Gabriel"
# age = 21
# height = 1.75
# ```
#
# Python determines the type of each value at runtime, providing flexibility and allowing developers to write code with less boilerplate.
#
# In contrast, language as **C** you need to typed:
#
# ```C
# ▶ string name = "Gabo";
# ▶ int age = 21;
# ▶ float height = 1.75;
# ```
#
# ---
#
# ## 🚀 Common Uses of Python
#
# Python's versatility allows it to be used across a wide range of fields:
#
# | ⛩ Area                                | 🔧 Examples                                             |
# | -------------------------------------- | ------------------------------------------------------- |
# | 🌐 **Web Development**                 | Django, Flask, FastAPI                                  |
# | 📊 **Data Science & Machine Learning** | NumPy, pandas, TensorFlow, scikit-learn                 |
# | 🤖 **Automation & Scripting**          | Task automation, file processing, system administration |
# | 💻 **Software Development**            | Desktop applications, games, APIs                       |
# | 🔬 **Scientific Computing**            | SciPy, Matplotlib, Jupyter                              |
# | 🧠 **Artificial Intelligence**         | Machine Learning, Deep Learning, NLP, Generative AI     |
#
# ### 🌐 Web Development
#
# Frameworks such as **Django, Flask, and FastAPI** allow developers to create web applications and APIs efficiently.
#
# ### 📊 Data Science & Machine Learning
#
# Python has become particularly popular in **data analysis, machine learning, and artificial intelligence** thanks to libraries such as **NumPy, pandas, TensorFlow, PyTorch, and scikit-learn**.
#
# ### ⚡ Scripting & Automation
#
# Python is widely used to automate repetitive tasks, manipulate files, process data, interact with APIs, and perform system administration tasks.
#
# ### 💻 Software Development
#
# Python can also be used to create **desktop applications, games, command-line tools, and backend services**, with libraries and frameworks such as **PyQt, Tkinter, and Pygame**.
#
# ### 🔬 Scientific Computing
#
# Python plays an important role in scientific and engineering research. Libraries such as **SciPy, NumPy, and Matplotlib** provide powerful tools for numerical computation, data analysis, visualization, and experimentation.
#
# ---
#
# ## 💡 Why Learn Python?
#
# Python combines **simplicity, flexibility, and a powerful ecosystem**, making it useful for learning fundamental programming concepts while also being capable of supporting advanced professional and scientific applications.
#
# > **Python's philosophy can be summarized in one idea:**
# >
# > *Simple is better than complex.*
#
# ---
#
# ### 📝 Summary
#
# **Python = Readability + Simplicity + Versatility + Powerful Ecosystem**
#
# These characteristics make Python an excellent language for **software development, data science, artificial intelligence, automation, and scientific research**.

# %% [markdown]
# # 🐍 Pythonプログラミング言語
#
# > **Python**は、シンプルで読みやすく、さまざまな用途に利用できることで知られている、高水準の汎用プログラミング言語です。
#
# 豊富なライブラリやフレームワークのエコシステムを持つことから、Pythonは現在、ソフトウェア開発、データサイエンス、人工知能、業務の自動化、科学技術計算など、幅広い分野で利用されている代表的なプログラミング言語の一つとなっています。
#
# ---
#
# ## ✨ Pythonの主な特徴
#
# ### 1. 🏗️ 高水準言語（High-Level Language）
#
# Pythonは、コンピューターのハードウェアやメモリ管理など、低レベルで行われる多くの処理を抽象化します。
# そのため、開発者はハードウェア固有の命令を細かく扱うことよりも、**問題を解決することやアプリケーションを作成すること**に集中できます。
#
# ### 2. ⚙️ インタプリタ型・対話型（Interpreted and Interactive）
#
# Pythonのプログラムは、Pythonインタプリタを通して実行されます。そのため、コードを対話的に実行しながら、アイデアをすぐに試すことができます。
#
# また、この方法によって、**実験、デバッグ、迅速な開発も行いやすく**なります。
#
# ### 3. 📖 読みやすくシンプルな構文
#
# Pythonの最も特徴的な点の一つは、**コードの読みやすさを重視していることです。**
#
# 他の多くのプログラミング言語では、{} などの記号を使ってコードブロックを定義します。一方、Pythonでは**インデント**を使ってコードブロックを表します。そのため、コードの構造が分かりやすく、見た目にも整理された構文になります。
#
# ただし、注意しなければ、Pythonのコードが読みにくくなることもあります。これは、コードをどれだけ分かりやすく書いているかにも左右されます。
#
# ```python
# if temperature > 30:
#     print("It's a hot day!")
# ```
#
# ### 4. 🔄 動的型付け
#
# Python is a **dynamically typed language**, meaning that variables do not require an explicit type declaration.
#
# Pythonは**動的型付けのプログラミング言語**です。つまり、変数を定義するときに、データ型を明示的に指定する必要がありません。
#
# ```python
# name = "Gabriel"
# age = 21
# height = 1.75
# ```
#
# Pythonは、プログラムの実行時に、それぞれの値のデータ型を自動的に判断します。
#
# この仕組みにより、Pythonでは柔軟にコードを書くことができ、必要な定型コードを減らしながらプログラムを作成できます。
#
# 一方、**C**言語などの言語では、変数を宣言するときにデータ型を指定する必要があります:
#
# ```C
# ▶ string name = "Gabo";
# ▶ int age = 21;
# ▶ float height = 1.75;
# ```
# ---
#
# ## 🚀 Pythonの主な利用分野
#
# Pythonは、**汎用性（はんようせい）**が高いため、さまざまな分野で幅広く利用されています。
#
# | ⛩ 分野 | 🔧 主な例 |
# | -------------------------------- | ------------------------------------------------------- |
# | 🌐 **Web開発** | Django、Flask、FastAPI |
# | 📊 **データサイエンス・機械学習** | NumPy、pandas、TensorFlow、scikit-learn |
# | 🤖 **自動化・スクリプト** | 業務の自動化、ファイル処理、システム管理 |
# | 💻 **ソフトウェア開発** | デスクトップアプリケーション、ゲーム、API |
# | 🔬 **科学技術計算** | SciPy、Matplotlib、Jupyter |
# | 🧠 **人工知能** | 機械学習、ディープラーニング、自然言語処理、生成AI |
#
# ### 🌐 Web開発
#
# **Django、Flask、FastAPI**などのフレームワークを利用することで、WebアプリケーションやAPIを効率的に開発できます。
#
# Pythonは、Webサービスの開発に必要なさまざまな機能を利用できるため、比較的少ないコードでアプリケーションを作成することも可能です。
#
# ### 📊 データサイエンス・機械学習
#
# Pythonは、**データ分析、機械学習、人工知能**の分野で特に広く利用されています。
#
# その理由の一つとして、**NumPy、pandas、TensorFlow、PyTorch、scikit-learn**など、豊富なライブラリが利用できることが挙げられます。
#
# これらのライブラリを使用することで、データの処理や分析、機械学習モデルの構築、AIに関するさまざまな処理を効率的に行うことができます。
#
# ### ⚡ スクリプト・自動化
#
# Pythonは、繰り返し行う作業を自動化したり、ファイルを操作したり、データを処理したり、APIと連携したりするためにも広く利用されています。
#
# また、システム管理に必要な処理を自動化することもできます。
#
# 例えば、毎日同じ作業を手動で行う代わりに、Pythonのプログラムを使って自動的に実行することができます。
#
# ### 💻 ソフトウェア開発
#
# Pythonは、**デスクトップアプリケーション、ゲーム、コマンドラインツール、バックエンドサービス**などの開発にも利用できます。
#
# 例えば、**PyQt、Tkinter、Pygame**などのライブラリやフレームワークを利用することで、さまざまな種類のソフトウェアを開発できます。
#
# ### 🔬 科学技術計算
#
# Pythonは、科学や工学分野の研究でも重要な役割を果たしています。
#
# **SciPy、NumPy、Matplotlib**などのライブラリを利用することで、数値計算、データ分析、データの可視化、実験などを効率的に行うことができます。
#
# ---
#
# ## 💡 なぜPythonを学ぶのか？
#
# Pythonは、**シンプルさ、柔軟性、そして豊富なエコシステム**を兼ね備えています。
#
# そのため、プログラミングの基本的な考え方を学ぶためにも適しており、さらに、高度な専門分野や科学技術分野で利用されるアプリケーションの開発にも対応できます。
#
# > **Pythonの考え方は、次の一つの言葉で表すことができます。**
# >
# > *Simple is better than complex.*
#
# ---
#
# ### 📝 まとめ
#
# **Python = 読みやすさ + シンプルさ + 汎用性 + 豊富なエコシステム**
#
# これらの特徴によって、Pythonは**ソフトウェア開発、データサイエンス、人工知能、自動化、科学研究**など、幅広い分野で活用されています。

# %% [markdown]
# ###Core areas
# - Indentation
# - Data types and operators
# - Variables and type conversion
# - Lists and other collections

# %% [markdown]
# ## 🧠 Pythonの基本的な分野
#
# Pythonを学ぶときは、まず次のような基本分野を理解することが重要です。
#
# - **インデント（Indentation）**
# - **データ型と演算子（Data Types and Operators）**
# - **変数と型変換（Variables and Type Conversion）**
# - **リストなどのコレクション（Lists and Other Collections）**
# - **条件分岐とループ（Conditions and Loops）**

# %%
# 💻 Example — Comments and Indentation

# This is a comment.
name = "Gabriel"

if name:
    print("Hello,", name)

# %% [markdown]
# ### 🧪 Exercise — Comments & Indentation
#
# Create a variable called `language` with the value `"Python"` and print:
#
# `I am learning Python.`

# %%
# ✍️ Your solution

language = "Python"

# Write your solution below.

# %% [markdown]
# ## Comments and Indentation
# Python programs are built from:
# - **Values**: `10`, `Hello`, `True`
# - **Variables**: names that reference values
# - **Expressions**: code that produces a value
# - **Statements**: Instructions executed by Python
#
# ### Comments
# ```python
# #This is a single-line comment
# ```
#
# ### Indentation
#
# Python uses indentation to define blocks
# ```python
# if score >= 70:
#   print("Pass")
# ```

# %% [markdown]
# ## コメントとインデント
# Pythonのプログラムは、主に次の4つの要素から構成されています:
# - **値**：`10`、`"Hello"`、`True` など、プログラムで実際に扱うデータ
# - **変数**：値を参照するための名前
# - **式**：値を計算したり、結果を生成したりするコード
# - **文**：Pythonが実行する一つ一つの命令
#
# ### コメント
# ```python
# #This is a single-line comment
# ```
# 上の例では、# から行の最後までがコメントとして扱われます。
#
#
#
# ### インデント
#
# Pythonでは、インデントを使ってコードのブロックを定義します。
# ```python
# if score >= 70:
#   print("Pass")
# ```

# %% [markdown]
# ## Variables
# A variable is a name bound to a value
# ```python
# name= "Ana"
# age = 20
# score = 95.5
# active = True
# ```
#
# ### Assignment operators
# | Operator | Meaning |
# |---|---|
# | `=` | assign |
# | `+=` | add and assign |
# | `-=` | subtract and assign |
# | `*=` | multiply and assign |
# | `/=` | divide and assign |
# | `//=` | floor-divide and assign |
# | `%=` | remainder and assign |
# | `**=` | power and assign |

# %%
# 💻 Example — Variables

name = "Ana"
age = 20
score = 95.5
active = True

print(name)
print(age)
print(score)
print(active)

# %%
# 🔎 Inspecting variable types

print(type(name))
print(type(age))
print(type(score))
print(type(active))

# %% [markdown]
# ### 🧪 Exercise — Variables
#
# Create four variables:
#
# - `student_name`
# - `student_age`
# - `average_score`
# - `is_studying`
#
# Then print all four values.

# %%
# ✍️ Your solution

# Write your variables and print statements here.

# %% [markdown]
# ## 変数
# 変数とは、値に結び付けられた名前です。
# ```python
# name= "Ana"
# age = 20
# score = 95.5
# active = True
# ```
#
# ### 代入演算子
# | 演算子 | 意味 |
# |---|---|
# | `=` | 代入する |
# | `+=` | 追加して代入する |
# | `-=` | 減算して代入する |
# | `*=` | 乗算して代入する |
# | `/=` | 除算して代入する |
# | `//=` | 切り捨て除算して代入する |
# | `%=` | 剰余を求めて代入する |
# | `**=` | 累乗して代入する |

# %% [markdown]
# ## Data Types
# The main basic types are:
#
# | Type | Example |
# |---|---|
# | `int` | `10` |
# | `float` | `10.5` |
# | `str` | `"Python"` |
# | `bool` | `True`, `False` |

# %%
# 💻 Example — Data Types

integer_value = 10
float_value = 10.5
text_value = "Python"
boolean_value = True

print(type(integer_value))
print(type(float_value))
print(type(text_value))
print(type(boolean_value))

# %% [markdown]
# ### 🧪 Exercise — Data Types
#
# Create one variable for each of these types:
#
# `int`, `float`, `str`, `bool`
#
# Use `type()` to verify each one.

# %%
# ✍️ Your solution

# Write your variables here and inspect their types.

# %% [markdown]
# ## データ型
# 主な基本データ型は次のとおりです:
#
# | 型 | 例 |
# |---|---|
# | `int` | `10` |
# | `float` | `10.5` |
# | `str` | `"Python"` |
# | `bool` | `True`, `False` |

# %% [markdown]
# ## Operators
#
# ### Aritmetics
#
# | Operator | Meaning | Example |
# |---|---|---|
# | `+` | addition | `5 + 2` → `7` |
# | `-` | subtraction | `5 - 2` → `3` |
# | `*` | multiplication | `5 * 2` → `10` |
# | `/` | division | `5 / 2` → `2.5` |
# | `//` | floor division | `5 // 2` → `2` |
# | `%` | remainder | `5 % 2` → `1` |
# | `**` | exponent | `5 ** 2` → `25` |
#
# ### Comparison
#
# `==`, `!=`, `>`, `<`, `>=`, `<=`
#
# ## Logical
#
# `and`, `not`, `or`
#
# ## Identity
# `is`, `is not`
#
# ### Membership
# `in`, `not in`

# %%
# 💻 Example — Operators

a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor division:", a // b)
print("Modulo:", a % b)
print("Power:", a ** b)

print("a == b:", a == b)
print("a > b:", a > b)
print("a != b:", a != b)

# %% [markdown]
# ### 🧪 Exercise — Operators
#
# Using `x = 15` and `y = 4`, calculate:
#
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Floor division
# 6. Remainder
# 7. Power

# %%
# ✍️ Your solution

x = 15
y = 4

# Write your calculations here.

# %% [markdown]
# ## 演算子
#
# ### 算術演算子
#
# | 演算子 | 意味 | 例 |
# |---|---|---|
# | `+` | 加算 | `5 + 2` → `7` |
# | `-` | 減算 | `5 - 2` → `3` |
# | `*` | 乗算 | `5 * 2` → `10` |
# | `/` | 除算 | `5 / 2` → `2.5` |
# | `//` | 切り捨て除算 | `5 // 2` → `2` |
# | `%` | 剰余 | `5 % 2` → `1` |
# | `**` | 累乗 | `5 ** 2` → `25` |
#
# ### 比較演算子
#
# `==`、`!=`、`>`、`<`、`>=`、`<=`
#
# ## 論理演算子
#
# `and`、`not`、`or`
#
# ## 同一性演算子
#
# `is`、`is not`
#
# ### メンバーシップ演算子
#
# `in`、`not in`

# %% [markdown]
# ## Strings
#
# Strings are sequences of characters
#
# ```python
# text = "Python"
#
# print(text[0])      # P
# print(text[-1])     # n
# print(text[1:4])    # yth
# print(text[:3])     # Pyt
# print(text[3:])     # hon
# ```
#
# ### Useful methods
#
# ```python
# text.lower()
# text.upper()
# text.strip()
# text.replace("Py", "My")
# text.split(",")
# ```

# %%
# 💻 Example — Strings

text = "Python"

print(text[0])
print(text[-1])
print(text[0:3])

print(text.lower())
print(text.upper())
print(text.replace("Python", "Data Science"))

# %% [markdown]
# ### 🧪 Exercise — Strings
#
# Create a string containing your name.
#
# Then:
#
# - print the first character;
# - print the last character;
# - convert it to uppercase;
# - convert it to lowercase.

# %%
# ✍️ Your solution

name = "Gabriel"

# Write your operations here.

# %% [markdown]
# ## 🇯🇵 文字列（Strings）
#
# **文字列（String）**は、文字の並びを表すデータです。
#
# ```python
# text = "Python"
# ```
#
# ### インデックス指定（Indexing）
#
# ```python
# text[0]     # P
# text[-1]    # n
# ```
#
# ### スライス（Slicing）
#
# ```python
# text[0:3]   # Pyt
# ```
#
# ### よく使うメソッド
#
# - `lower()` → 小文字に変換
# - `upper()` → 大文字に変換
# - `strip()` → 前後の空白を削除
# - `replace()` → 文字列を置換
# - `split()` → 文字列を分割

# %% [markdown]
# ## Collections
#
# Python commonly uses:
#
# - **List**  → ordered, mutable
# - **Tuple** → ordered, immutable
# - **Dictionary** → key-value pairs
# - **Set** → unordered collection of unique values
#
# | Structure | Mutable? | Example |
# |---|---:|---|
# | List | Yes | `[1, 2, 3]` |
# | Tuple | No | `(1, 2, 3)` |
# | Dictionary | Yes | `{"name": "Ana"}` |
# | Set | Yes | `{1, 2, 3}` |

# %% [markdown]
# ## コレクション
#
# Pythonでは、一般的に次のようなコレクションが使用されます:
#
# - **リスト** → 順序があり、変更可能
# - **タプル** → 順序があり、変更不可
# - **辞書** → キーと値のペア
# - **集合** → 順序がなく、重複しない値のコレクション
#
# | 構造  | 変更可能 | 例 |
# |---|---:|---|
# | List | はい | `[1, 2, 3]` |
# | Tuple | いいえ | `(1, 2, 3)` |
# | Dictionary | はい | `{"name": "Ana"}` |
# | Set | はい | `{1, 2, 3}` |

# %%
# 💻 Example — Lists

numbers = [10, 20, 30]

print(numbers[0])
print(numbers[-1])
print(numbers[0:2])

numbers.append(40)
numbers.insert(1, 15)

print(numbers)

numbers.remove(15)
last_value = numbers.pop()

print(numbers)
print("Removed:", last_value)

# %%
# 🔎 Useful list operations

numbers = [10, 20, 30, 40]

print("Length:", len(numbers))
print("Maximum:", max(numbers))
print("Minimum:", min(numbers))

numbers.sort()
print("Sorted:", numbers)

numbers.reverse()
print("Reversed:", numbers)

# %% [markdown]
# ### 🧪 Exercise — Lists
#
# Create a list containing five numbers.
#
# Then:
#
# 1. access the first element;
# 2. access the last element;
# 3. add a new number;
# 4. remove one number;
# 5. print the length of the list.

# %%
# ✍️ Your solution

# Create your list and complete the requested operations.

# %% [markdown]
# ## Lists
#
# Lists are one of the most important topics.
#
# ```python
# numbers = [10, 20, 30]
# ```
#
# ### Indexing
#
# ```python
# numbers[0]      # 10
# numbers[-1]     # 30
# ```
#
# ### Slicing
#
# ```python
# numbers[0:2]    # [10, 20]
# numbers[:2]     # [10, 20]
# numbers[1:]     # [20, 30]
# ```
#
# ### Common list methods
#
# ```python
# numbers.append(40)       # add at end
# numbers.insert(1, 15)    # insert at index
# numbers.remove(20)       # remove by value
# numbers.pop()            # remove last item
# numbers.sort()           # sort in place
# numbers.reverse()        # reverse in place
# ```
#
# Useful functions:
#
# ```python
# len(numbers)
# max(numbers)
# min(numbers)
# ```

# %% [markdown]
# ## リスト
#
# リストは、特に重要な項目の一つです。
#
# ```python
# numbers = [10, 20, 30]
# ```
#
# ### インデックス指定
#
# ```python
# numbers[0]      # 10
# numbers[-1]     # 30
# ```
#
# ### スライス
#
# ```python
# numbers[0:2]    # [10, 20]
# numbers[:2]     # [10, 20]
# numbers[1:]     # [20, 30]
# ```
#
# ### よく使用するリストのメソッド
#
# ```python
# numbers.append(40)       # add at end
# numbers.insert(1, 15)    # insert at index
# numbers.remove(20)       # remove by value
# numbers.pop()            # remove last item
# numbers.sort()           # sort in place
# numbers.reverse()        # reverse in place
# ```
#
# 便利な関数：
#
# ```python
# len(numbers)
# max(numbers)
# min(numbers)
# ```

# %%
# サンプルコード

x=10
y=5
result=x+y
print(result)

name = "Gabriel"
age = 25
print(name)
print(age)

print(type(age))
print(type(name))

#算数オペレーター
a=10
b=3

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)

#比較演算子
x = 10
y = 5

print(x == y)
print(x != y)
print(x > y)
print(x < y)
print(x >= y)
print(x <= y)

# %% [markdown]
# # 🧪 Final Practice
#
# Use the concepts from this notebook to create a small Python program.
#
# ### Challenge
#
# Create variables representing:
#
# - a student's name;
# - age;
# - three grades;
# - whether the student is active.
#
# Calculate the average of the three grades and display a short report.
#
# Try to use:
#
# - variables;
# - data types;
# - arithmetic operators;
# - `print()`;
# - at least one string operation.

# %%
# 🚀 Mini Challenge — Student Report

# Write your solution here.

# %% [markdown]
# ---
#
# # 🔗 Return to the Learning Library
#
# This notebook belongs to:
#
# **`python/Basics_of_Python1.ipynb`**
#
# ### Navigation
#
# - [🏠 GCI Learning Library — GitHub](https://github.com/GabrielRamos1171998/GCI-World-2026-September/blob/main/home/GCI_Learning_Library.ipynb)
# - [🏠 GCI Learning Library — Colab](https://colab.research.google.com/github/GabrielRamos1171998/GCI-World-2026-September/blob/main/home/GCI_Learning_Library.ipynb)
# - [📄 Basics of Python 1 — GitHub](https://github.com/GabrielRamos1171998/GCI-World-2026-September/blob/main/python/Basics_of_Python1.ipynb)
# - [🔵 Basics of Python 1 — Open in Colab](https://colab.research.google.com/github/GabrielRamos1171998/GCI-World-2026-September/blob/main/python/Basics_of_Python1.ipynb)
#
# > The links above are intentionally absolute so that the notebook remains navigable when opened from GitHub or Google Colab.
